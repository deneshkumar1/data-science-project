# %%
import numpy as np
import pandas as pd
# !pip install mlxtend
import mlxtend
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# Out:
# Collecting mlxtend
#   Using cached mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\dines\anaconda3\lib\site-packages (from mlxtend) (3.3.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\dines\anaconda3\lib\site-packages (from mlxtend) (1.10.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\dines\anaconda3\lib\site-packages (from mlxtend) (1.0.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\dines\anaconda3\lib\site-packages (from mlxtend) (1.23.5)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\dines\anaconda3\lib\site-packages (from mlxtend) (2.0.1)
# Requirement already satisfied: setuptools in c:\users\dines\anaconda3\lib\site-packages (from mlxtend) (52.0.0.post20210125)
# Collecting scikit-learn>=1.0.2
#   Downloading scikit_learn-1.3.0-cp38-cp38-win_amd64.whl (9.2 MB)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 171, in _merge_into_criterion
#     crit = self.state.criteria[name]
# KeyError: 'scikit-learn'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\dines\anaconda3\lib\http\client.py", line 458, in read
#     n = self.readinto(b)
#   File "C:\Users\dines\anaconda3\lib\http\client.py", line 502, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\dines\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\dines\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\dines\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 189, in _main
#     status = self.run(options, args)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 178, in wrapper
#     return func(self, options, args)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 316, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 121, in resolve
#     self._result = resolver.resolve(
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 453, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 347, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name, criterion)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 207, in _attempt_to_pin_criterion
#     criteria = self._get_criteria_to_update(candidate)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 199, in _get_criteria_to_update
#     name, crit = self._merge_into_criterion(r, parent=candidate)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 173, in _merge_into_criterion
#     crit = Criterion.from_requirement(self._p, requirement, parent)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 82, in from_requirement
#     if not cands:
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 124, in __bool__
#     return bool(self._sequence)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in __bool__
#     return any(self)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 38, in _iter_built
#     candidate = func()
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 167, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 300, in __init__
#     super().__init__(
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 144, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 226, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 311, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 457, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 480, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 230, in unpack_url
#     file = get_http_url(
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 108, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 163, in __call__
#     for chunk in chunks:
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\cli\progress_bars.py", line 159, in iter
#     for x in it:
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 64, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\dines\anaconda3\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\dines\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-0f30ce2e6867> in <module>
#       2 import pandas as pd
#       3 get_ipython().system('pip install mlxtend')
# ----> 4 import mlxtend
#       5 from mlxtend.frequent_patterns import apriori
#       6 from mlxtend.frequent_patterns import association_rules
#
# ModuleNotFoundError: No module named 'mlxtend'
